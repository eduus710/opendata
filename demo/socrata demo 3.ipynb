# %%
import csv
import mysql.connector

SCHEMA_NAME = 'odmeta'
CAT_DS_NAME = 'catalog_dataset'
CAT_COL_NAME = 'catalog_column'

# generate and execute DROP TABLE for socrata ddg catalog tables  
#
def drop_catalog_tables(mycursor):
    ddl = "DROP TABLE IF EXISTS {}.{};\n".format(SCHEMA_NAME, CAT_DS_NAME)
    if mycursor is not None:
        mycursor.execute(ddl)
    ddl = "DROP TABLE IF EXISTS {}.{};\n".format(SCHEMA_NAME, CAT_COL_NAME)
    if mycursor is not None:
        mycursor.execute(ddl)
    return ddl
    
def create_catalog_tables(mycursor):
    ddl = "CREATE TABLE {}.{} (\n".format(SCHEMA_NAME, CAT_DS_NAME)
    ddl += "domain_id CHAR(4) NOT NULL,\n"
    ddl += "dataset_id CHAR(9) NOT NULL,\n"
    ddl += "name VARCHAR(255) NOT NULL,\n"
    ddl += "description TEXT NOT NULL,\n"
    ddl += "PRIMARY KEY(domain_id, dataset_id))\n"
    if mycursor is not None:
        mycursor.execute(ddl)
    print(ddl)
            
    ddl = "CREATE TABLE {}.{} (\n".format(SCHEMA_NAME, CAT_COL_NAME)
    ddl += "domain_id CHAR(4) NOT NULL,\n"
    ddl += "dataset_id VARCHAR(255) NOT NULL,\n"
    ddl += "field_name VARCHAR(255) NOT NULL,\n"
    ddl += "name VARCHAR(255) NOT NULL,\n"
    ddl += "datatype VARCHAR(255) NOT NULL,\n"
    ddl += "format VARCHAR(255) NOT NULL,\n"
    ddl += "description TEXT NOT NULL,\n"
    ddl += "PRIMARY KEY(domain_id, dataset_id,field_name))\n\n"
    if mycursor is not None:
        mycursor.execute(ddl)
    print(ddl)
    
    return ddl

# %%
print (drop_catalog_tables(None))
# Out:
# DROP TABLE IF EXISTS odmeta.catalog_column;

# %%
print (create_catalog_tables(None))
# Out:
# CREATE TABLE odmeta.catalog_dataset (
# domain_id CHAR(4) NOT NULL,
# dataset_id CHAR(9) NOT NULL,
# name VARCHAR(255) NOT NULL,
# description TEXT NOT NULL,
# PRIMARY KEY(domain_id, dataset_id))
#
# CREATE TABLE odmeta.catalog_column (
# domain_id CHAR(4) NOT NULL,
# dataset_id VARCHAR(255) NOT NULL,
# field_name VARCHAR(255) NOT NULL,
# name VARCHAR(255) NOT NULL,
# datatype VARCHAR(255) NOT NULL,
# format VARCHAR(255) NOT NULL,
# description TEXT NOT NULL,
# PRIMARY KEY(domain_id, dataset_id,field_name))
#
#
# CREATE TABLE odmeta.catalog_column (
# domain_id CHAR(4) NOT NULL,
# dataset_id VARCHAR(255) NOT NULL,
# field_name VARCHAR(255) NOT NULL,
# name VARCHAR(255) NOT NULL,
# datatype VARCHAR(255) NOT NULL,
# format VARCHAR(255) NOT NULL,
# description TEXT NOT NULL,
# PRIMARY KEY(domain_id, dataset_id,field_name))

# %%
def insert_catalog_table(mydb, domain, ds):
    ddl = "INSERT INTO {}.{} ".format(SCHEMA_NAME, CAT_DS_NAME)
    ddl += "VALUES (%s,%s,%s,%s)\n"
    if mydb is not None:
        mydb._db_cur.execute(ddl, (domain, ds['id'],ds['name'],ds['description']))
        print( mydb._db_cur.statement)

    ddl = "INSERT INTO {}.{} ".format(SCHEMA_NAME, CAT_COL_NAME)
    ddl += "VALUES (%s,%s,%s,%s,%s,%s,%s)\n"
    print(ddl)
    # zip the column-related attributes into a single list
    col_count = len(ds['columns_name'])
    domain_ids = [domain] * col_count
    ds_ids = [ds['id']] * col_count
    col_formats = [str(col_format) for col_format in ds['columns_format']]
    cols = zip(domain_ids, ds_ids, ds['columns_field_name'], ds['columns_name'], ds['columns_datatype'],
               col_formats, ds['columns_description'])
    cols = list(cols)
    print("cols ", len(cols))
    print("row ", len(cols[0]))
    if mydb is not None:
        mydb._db_cur.executemany(ddl, cols)
        print(mydb._db_cur.statement)
        print (mydb._db_cur.rowcount, "Record inserted successfully")

# %%
import requests

domain = 'odde'

# Retrieve DDG catalog from socrata
# returns JSON
#
def fetch_catalog():
    resp = requests.get("http://api.us.socrata.com/api/catalog/v1?domains=data.delaware.gov")
    return resp.json()

catalog = fetch_catalog()
catalog['results'][1]
# Out:
# {'resource': {'name': 'Restaurant Inspection Violations',
#   'id': '384s-wygj',
#   'parent_fxf': None,
#   'description': 'Because of a technical issue, the Department of Health and Social Services has not been able to update online restaurant inspection data since May 2017.  Since the Open Data Portal cannot provide current digital inspection data, we are removing the dataset from public view until this issue can be resolved.  The Division of Public Health is actively pursuing resolution of this issue through implementation of a new database system to house and manage the information, which is anticipated to be in place in 2018.  If you have any questions regarding a food inspection report conducted after May 2017, please contact the Office of Food Protection in the Division of Public Health at 302-744-4546.\r\n\r\n\r\n\r\nThis is a public use data file on Delaware restaurant inspections from January 1, 2016 through present. It includes a list of restaurants with violations reported during the inspection of the establishment.',
#   'attribution': 'Department of Health and Social Services, Division of Public Health, Office of Food Protection',
#   'type': 'dataset',
#   'updatedAt': '2017-12-19T18:33:23.000Z',
#   'createdAt': '2016-08-03T18:25:47.000Z',
#   'page_views': {'page_views_last_week': 18,
#    'page_views_last_month': 39,
#    'page_views_total': 57430,
#    'page_views_last_week_log': 4.247927513443585,
#    'page_views_last_month_log': 5.321928094887363,
#    'page_views_total_log': 15.809542061985224},
#   'columns_name': ['Violation 8 Description',
#    'Violation 8',
#    'Violation 7 Description',
#    'Violation 7',
#    'Violation 10 Description',
#    'Violation 10',
#    'Violation 9 Description',
#    'Violation 9',
#    'Violation 4 Description',
#    'Violation 4',
#    'Violation 3 Description',
#    'Violation 3',
#    'Violation 6 Description',
#    'Violation 6',
#    'Violation 5 Description',
#    'Violation 5',
#    'Inspection Type',
#    'Inspection Date',
#    'Food Establishment Zip Code',
#    'Violation 2 Description',
#    'Violation 12 Desription',
#    'Violation 12',
#    'Violation 11 Description',
#    'Violation 11',
#    'Geocoded Location',
#    'Violation 13 Description',
#    'Violation 13',
#    'Violation 2',
#    'Violation 1 Description',
#    'Violation 1',
#    'Food Establishment City',
#    'Food Establishment Street Address',
#    'Food Establishment Name'],
#   'columns_field_name': ['vio_8_desc',
#    'vio_8',
#    'vio_7_desc',
#    'vio_7',
#    'vio_10_desc',
#    'vio_10',
#    'vio_9_desc',
#    'vio_9',
#    'vio_4_desc',
#    'vio_4',
#    'vio_3_desc',
#    'vio_3',
#    'vio_6_desc',
#    'vio_6',
#    'vio_5_desc',
#    'vio_5',
#    'name',
#    'ddate',
#    'pepzip',
#    'vio_2_desc',
#    'vio_12_desc',
#    'vio_12',
#    'vio_11_desc',
#    'vio_11',
#    'geocoded_location',
#    'vio_13_desc',
#    'vio_13',
#    'vio_2',
#    'vio_1_desc',
#    'vio_1',
#    'pepcity',
#    'pepaddress',
#    'pepname'],
#   'columns_datatype': ['Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Calendar date',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Location',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text',
#    'Text'],
#   'columns_description': ['Description of eighth cited violation',
#    'Eighth cited violation',
#    'Description of seventh cited violation',
#    'Seventh cited violation',
#    'Description of tenth cited violation.',
#    'Tenth cited violation',
#    'Description of ninth cited violation.',
#    'Ninth cited violation',
#    'Description of fourth cited violation',
#    'Fourth cited violation',
#    'Description of third cited violation',
#    'Third cited violation',
#    'Description of sixth cited violation',
#    'Sixth cited violation',
#    'Description of fifth cited violation',
#    'Fifth cited violation',
#    'Inspection visit type:  routine, follow-up, or complaint.',
#    'Date of restaurant inspection conducted by the Division of Public Health - Office of Food Protection',
#    'Restaurant Zip Code',
#    'Description of second cited violation',
#    'Description of twelfth cited violation',
#    'Twelfth cited violation',
#    'Description of eleventh cited violation',
#    'Eleventh cited violation',
#    'Geocoded location for mapping purposes.  Mashup of street address, city, state and zip code.',
#    'Description of thirteenth cited violation',
#    'Thirteenth cited violation',
#    'Second cited violation',
#    'Description of the first cited violation',
#    'First cited violation',
#    'Restaurant city',
#    'Restaurant street address',
#    'Restaurant name'],
#   'columns_format': [{'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'view': 'date', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'view': 'address_coords', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'},
#    {'displayStyle': 'plain', 'align': 'left'}],
#   'download_count': 592,
#   'provenance': 'official'},
#  'classification': {'categories': [],
#   'tags': [],
#   'domain_category': 'Health',
#   'domain_tags': ['violation',
#    'food',
#    'establishment',
#    'inspection',
#    'restaurant inspection violations'],
#   'domain_metadata': [{'key': 'Additional-Information_Temporal-Coverage',
#     'value': 'January 1, 2016 - present'},
#    {'key': 'Additional-Information_Frequency-of-publishing',
#     'value': 'Monthly'},
#    {'key': 'Additional-Information_Geographic-Unit',
#     'value': 'Street Address'}]},
#  'metadata': {'domain': 'data.delaware.gov', 'license': 'Public Domain'},
#  'permalink': 'https://data.delaware.gov/d/384s-wygj',
#  'link': 'https://data.delaware.gov/Health/Restaurant-Inspection-Violations/384s-wygj',
#  'owner': {'id': 'thy9-8afe', 'display_name': 'DE Open Data'}}

# %%
# rip out the datasets for convenience
datasets = [r for r in [x['resource'] for x in catalog['results']]
    if r['type'] == 'dataset']
datasets

for ds in datasets:
    print(insert_catalog_table(None, domain, ds))
# Out:
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  13
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  33
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  14
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  34
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  79
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  10
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  15
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  8
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  8
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  7
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  10
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  11
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  21
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  10
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  21
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  80
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  10
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  37
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  20
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  8
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  61
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  24
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  7
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  15
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  18
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  18
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  152
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  16
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  12
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  34
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  14
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  8
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  4
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  21
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  15
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  10
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  11
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  13
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  13
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  18
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  6
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  8
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  10
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  13
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  15
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  17
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  12
# row  7
# None
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  9
# row  7
# None

# %%
class MyDB:
    def __init__(self):
        self._db_connection  = mysql.connector.connect(
            host='127.0.0.1',
            user='oddeuser',
            password='oddepass',
            db='odmeta',
            autocommit=True)
        self._db_cur = self._db_connection.cursor(prepared=True)

    def query(self, query, params=''):
        return self._db_cur.execute(query, params)

    def __del__(self):
        self._db_connection.close()
        
mydb = MyDB()

# %%
print(drop_catalog_tables(mydb._db_cur))
# Out:
# DROP TABLE IF EXISTS odmeta.catalog_column;

# %%
print(create_catalog_tables(mydb._db_cur))
# Out:
# CREATE TABLE odmeta.catalog_dataset (
# domain_id CHAR(4) NOT NULL,
# dataset_id CHAR(9) NOT NULL,
# name VARCHAR(255) NOT NULL,
# description TEXT NOT NULL,
# PRIMARY KEY(domain_id, dataset_id))
#
# CREATE TABLE odmeta.catalog_column (
# domain_id CHAR(4) NOT NULL,
# dataset_id VARCHAR(255) NOT NULL,
# field_name VARCHAR(255) NOT NULL,
# name VARCHAR(255) NOT NULL,
# datatype VARCHAR(255) NOT NULL,
# format VARCHAR(255) NOT NULL,
# description TEXT NOT NULL,
# PRIMARY KEY(domain_id, dataset_id,field_name))
#
#
# CREATE TABLE odmeta.catalog_column (
# domain_id CHAR(4) NOT NULL,
# dataset_id VARCHAR(255) NOT NULL,
# field_name VARCHAR(255) NOT NULL,
# name VARCHAR(255) NOT NULL,
# datatype VARCHAR(255) NOT NULL,
# format VARCHAR(255) NOT NULL,
# description TEXT NOT NULL,
# PRIMARY KEY(domain_id, dataset_id,field_name))

# %%
mydb._db_connection.get_warnings = True
for ds in datasets:
    insert_catalog_table(mydb, domain, ds)
# Out:
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  13
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 13 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  33
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 33 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  14
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 14 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  34
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 34 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  79
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 79 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  10
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 10 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  15
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 15 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  8
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 8 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  8
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 8 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  7
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 7 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  10
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 10 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  11
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 11 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  21
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 21 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  10
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 10 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  21
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 21 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  80
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 80 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  10
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 10 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  37
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 37 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  20
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 20 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  8
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 8 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  61
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 61 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  24
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 24 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  7
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 7 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  15
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 15 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  18
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 18 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  18
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 18 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  152
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 152 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  16
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 16 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  12
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 12 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  34
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 34 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  14
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 14 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  8
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 8 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  4
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 4 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  21
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 21 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  15
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 15 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  10
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 10 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  11
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 11 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  13
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 13 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  13
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 13 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  18
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 18 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  6
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 6 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  8
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 8 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  10
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 10 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  13
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 13 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  15
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 15 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  17
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 17 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  12
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 12 Record inserted successfully
# INSERT INTO odmeta.catalog_dataset VALUES (%s,%s,%s,%s)
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
#
# cols  9
# row  7
# INSERT INTO odmeta.catalog_column VALUES (%s,%s,%s,%s,%s,%s,%s)
# 9 Record inserted successfully
